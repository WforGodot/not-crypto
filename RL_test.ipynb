# %%
import gymnasium as gym

from stable_baselines3 import A2C

env = gym.make("CartPole-v1", render_mode="rgb_array")

model = A2C("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10_000)

vec_env = model.get_env()
obs = vec_env.reset()
for i in range(1000):
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, done, info = vec_env.step(action)
    vec_env.render("human")
    # VecEnv resets automatically
    # if done:
    #   obs = vec_env.reset()
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 22.5     |
# |    ep_rew_mean        | 22.5     |
# | time/                 |          |
# |    fps                | 70       |
# |    iterations         | 100      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -0.693   |
# |    explained_variance | -0.122   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 1.93     |
# |    value_loss         | 10.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 24.3     |
# |    ep_rew_mean        | 24.3     |
# | time/                 |          |
# |    fps                | 104      |
# |    iterations         | 200      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -0.676   |
# |    explained_variance | -0.114   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -8.48    |
# |    value_loss         | 135      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 26.3     |
# |    ep_rew_mean        | 26.3     |
# | time/                 |          |
# |    fps                | 122      |
# |    iterations         | 300      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.672   |
# |    explained_variance | 0.073    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 1.46     |
# |    value_loss         | 6.32     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 31       |
# |    ep_rew_mean        | 31       |
# | time/                 |          |
# |    fps                | 129      |
# |    iterations         | 400      |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.673   |
# |    explained_variance | 0.014    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 1.29     |
# |    value_loss         | 5.97     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 32.9     |
# |    ep_rew_mean        | 32.9     |
# | time/                 |          |
# |    fps                | 130      |
# |    iterations         | 500      |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.607   |
# |    explained_variance | -0.0194  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 0.857    |
# |    value_loss         | 5.3      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 34.7     |
# |    ep_rew_mean        | 34.7     |
# | time/                 |          |
# |    fps                | 129      |
# |    iterations         | 600      |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.681   |
# |    explained_variance | -0.00198 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 1.26     |
# |    value_loss         | 4.91     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 37.3     |
# |    ep_rew_mean        | 37.3     |
# | time/                 |          |
# |    fps                | 131      |
# |    iterations         | 700      |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -0.671   |
# |    explained_variance | 0.0175   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 1.06     |
# |    value_loss         | 4.28     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 39.7     |
# |    ep_rew_mean        | 39.7     |
# | time/                 |          |
# |    fps                | 134      |
# |    iterations         | 800      |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.51    |
# |    explained_variance | 0.0214   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 1.36     |
# |    value_loss         | 3.77     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 41.9     |
# |    ep_rew_mean        | 41.9     |
# | time/                 |          |
# |    fps                | 137      |
# |    iterations         | 900      |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.662   |
# |    explained_variance | 0.00471  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 0.922    |
# |    value_loss         | 3.25     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47       |
# |    ep_rew_mean        | 47       |
# | time/                 |          |
# |    fps                | 139      |
# |    iterations         | 1000     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.639   |
# |    explained_variance | 0.000433 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.738    |
# |    value_loss         | 2.81     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 51.8     |
# |    ep_rew_mean        | 51.8     |
# | time/                 |          |
# |    fps                | 139      |
# |    iterations         | 1100     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -0.621   |
# |    explained_variance | 0.00409  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.86     |
# |    value_loss         | 2.37     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 54.8     |
# |    ep_rew_mean        | 54.8     |
# | time/                 |          |
# |    fps                | 139      |
# |    iterations         | 1200     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.641   |
# |    explained_variance | 0.000137 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.671    |
# |    value_loss         | 1.98     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 58.6     |
# |    ep_rew_mean        | 58.6     |
# | time/                 |          |
# |    fps                | 140      |
# |    iterations         | 1300     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.457   |
# |    explained_variance | -0.0002  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 1.09     |
# |    value_loss         | 1.62     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 62.2      |
# |    ep_rew_mean        | 62.2      |
# | time/                 |           |
# |    fps                | 143       |
# |    iterations         | 1400      |
# |    time_elapsed       | 48        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -0.646    |
# |    explained_variance | -0.000117 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | 0.69      |
# |    value_loss         | 1.3       |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 66       |
# |    ep_rew_mean        | 66       |
# | time/                 |          |
# |    fps                | 147      |
# |    iterations         | 1500     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -0.623   |
# |    explained_variance | 3.33e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 0.48     |
# |    value_loss         | 1.01     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 70       |
# |    ep_rew_mean        | 70       |
# | time/                 |          |
# |    fps                | 150      |
# |    iterations         | 1600     |
# |    time_elapsed       | 53       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.574   |
# |    explained_variance | 8.89e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 0.455    |
# |    value_loss         | 0.752    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 74.2      |
# |    ep_rew_mean        | 74.2      |
# | time/                 |           |
# |    fps                | 152       |
# |    iterations         | 1700      |
# |    time_elapsed       | 55        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -0.597    |
# |    explained_variance | -4.91e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | 0.234     |
# |    value_loss         | 0.525     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 78.8      |
# |    ep_rew_mean        | 78.8      |
# | time/                 |           |
# |    fps                | 155       |
# |    iterations         | 1800      |
# |    time_elapsed       | 57        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -0.348    |
# |    explained_variance | -0.000105 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | 0.287     |
# |    value_loss         | 0.343     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 82.7      |
# |    ep_rew_mean        | 82.7      |
# | time/                 |           |
# |    fps                | 158       |
# |    iterations         | 1900      |
# |    time_elapsed       | 60        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -0.59     |
# |    explained_variance | -2.29e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | 0.149     |
# |    value_loss         | 0.199     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 85.9      |
# |    ep_rew_mean        | 85.9      |
# | time/                 |           |
# |    fps                | 160       |
# |    iterations         | 2000      |
# |    time_elapsed       | 62        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -0.599    |
# |    explained_variance | -1.65e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | 0.123     |
# |    value_loss         | 0.0974    |
# -------------------------------------
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\proje\anaconda3\envs\Latest\Lib\site-packages\gymnasium\envs\classic_control\cartpole.py:223, in CartPoleEnv.render(self)
#     222 try:
# --> 223     import pygame
#     224     from pygame import gfxdraw
#
# ModuleNotFoundError: No module named 'pygame'
#
# The above exception was the direct cause of the following exception:
#
# DependencyNotInstalled                    Traceback (most recent call last)
# Cell In[3], line 15
#      13 action, _state = model.predict(obs, deterministic=True)
#      14 obs, reward, done, info = vec_env.step(action)
# ---> 15 vec_env.render("human")
#      16 # VecEnv resets automatically
#      17 # if done:
#      18 #   obs = vec_env.reset()
#
# File c:\Users\proje\anaconda3\envs\Latest\Lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:103, in DummyVecEnv.render(self, mode)
#      96 def render(self, mode: Optional[str] = None) -> Optional[np.ndarray]:
#      97     """
#      98     Gym environment rendering. If there are multiple environments then
#      99     they are tiled together in one image via ``BaseVecEnv.render()``.
#     100
#     101     :param mode: The rendering type.
#     102     """
# --> 103     return super().render(mode=mode)
#
# File c:\Users\proje\anaconda3\envs\Latest\Lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:255, in VecEnv.render(self, mode)
#     251     return None
#     253 if mode == "rgb_array" or mode == "human":
#     254     # call the render method of the environments
# --> 255     images = self.get_images()
#     256     # Create a big image by tiling images from subprocesses
#     257     bigimg = tile_images(images)  # type: ignore[arg-type]
#
# File c:\Users\proje\anaconda3\envs\Latest\Lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:94, in DummyVecEnv.get_images(self)
#      90     warnings.warn(
#      91         f"The render mode is {self.render_mode}, but this method assumes it is `rgb_array` to obtain images."
#      92     )
#      93     return [None for _ in self.envs]
# ---> 94 return [env.render() for env in self.envs]
#
# File c:\Users\proje\anaconda3\envs\Latest\Lib\site-packages\gymnasium\core.py:471, in Wrapper.render(self)
#     469 def render(self) -> RenderFrame | list[RenderFrame] | None:
#     470     """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 471     return self.env.render()
#
# File c:\Users\proje\anaconda3\envs\Latest\Lib\site-packages\gymnasium\core.py:471, in Wrapper.render(self)
#     469 def render(self) -> RenderFrame | list[RenderFrame] | None:
#     470     """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 471     return self.env.render()
#
# File c:\Users\proje\anaconda3\envs\Latest\Lib\site-packages\gymnasium\wrappers\order_enforcing.py:70, in OrderEnforcing.render(self, *args, **kwargs)
#      65 if not self._disable_render_order_enforcing and not self._has_reset:
#      66     raise ResetNeeded(
#      67         "Cannot call `env.render()` before calling `env.reset()`, if this is a intended action, "
#      68         "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#      69     )
# ---> 70 return self.env.render(*args, **kwargs)
#
# File c:\Users\proje\anaconda3\envs\Latest\Lib\site-packages\gymnasium\wrappers\env_checker.py:65, in PassiveEnvChecker.render(self, *args, **kwargs)
#      63 if not self.checked_render:
#      64     self.checked_render = True
# ---> 65     return env_render_passive_checker(self.env, *args, **kwargs)
#      66 else:
#      67     return self.env.render(*args, **kwargs)
#
# File c:\Users\proje\anaconda3\envs\Latest\Lib\site-packages\gymnasium\utils\passive_env_checker.py:362, in env_render_passive_checker(env)
#     356     else:
#     357         assert env.render_mode is None or env.render_mode in render_modes, (
#     358             "The environment was initialized successfully however with an unsupported render mode. "
#     359             f"Render mode: {env.render_mode}, modes: {render_modes}"
#     360         )
# --> 362 result = env.render()
#     363 if env.render_mode is not None:
#     364     _check_render_return(env.render_mode, result)
#
# File c:\Users\proje\anaconda3\envs\Latest\Lib\site-packages\gymnasium\envs\classic_control\cartpole.py:226, in CartPoleEnv.render(self)
#     224     from pygame import gfxdraw
#     225 except ImportError as e:
# --> 226     raise DependencyNotInstalled(
#     227         "pygame is not installed, run `pip install gymnasium[classic-control]`"
#     228     ) from e
#     230 if self.screen is None:
#     231     pygame.init()
#
# DependencyNotInstalled: pygame is not installed, run `pip install gymnasium[classic-control]`

# %%
for i in range(100):
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, done, info = vec_env.step(action)
    vec_env.render("human")
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
